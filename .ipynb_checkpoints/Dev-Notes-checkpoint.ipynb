# %% [markdown]
# # Dev environment
#     1. ACG (A Cloud Guru) code-server setup
#        - create code server
#           ![new server](../../../../Pictures/Saved%20Pictures/ACG-new-server.jpg)

# %% [markdown]
# ![ACG-new-server.jpg](attachment:ACG-new-server.jpg)
